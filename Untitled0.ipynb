# %% [markdown]
# # jupytor
# ####### jupytor
# # karthik
# # siri
# # nihal
# # varun
# # rakesh
# # google
# # New Section

# %% [markdown]
# # jupyter
# - point 1
#     - *sub point* 1.1
#     - **sub point** 1.2
#     - ***sub point*** 1.3
# - point 2
# - point 3

# %% [markdown]
# ### Python Introduction
# - python 3
# - python can be used as Functional programming
# - python can be used as Script programming
# - python initially desined ***guide van rossum*** in 1991

# %% [markdown]
# # Input and Output function
# # Output function
# print()
