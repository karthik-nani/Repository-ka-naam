# %%
#List-->indexed,odered,mutable,allows duplicate values

# %%
list1 = [12,23,45.6,"abc",True]
list1.append(45.6)
list1.append(200)
print(list1)
list1.insert(2,15)
print(list1)
list1.extend([300,600,400,800])
print(list1)
# Out:
# [12, 23, 45.6, 'abc', True, 45.6, 200]
# [12, 23, 15, 45.6, 'abc', True, 45.6, 200]
# [12, 23, 15, 45.6, 'abc', True, 45.6, 200, 300, 600, 400, 800]

# %%
del list1[-1]
print(list1)
# Out:
# [12, 23, 15, 45.6, 'abc', True, 45.6, 200, 300, 600, 400]

# %%
list1.pop()
print(list1)
# Out:
# [12, 23, 15, 45.6, 'abc', True, 45.6, 200, 300, 600]

# %%
del list1[-1]
print(list1)
#r = list1.pop(4)
list1.remove(200)
print(list1)
# Out:
# [12, 23, 15, 45.6, 'abc', True, 45.6, 200, 300]
# [12, 23, 15, 45.6, 'abc', True, 45.6, 300]

# %%
list1.append(500)
list1
# Out:
# [12, 23, 15, 45.6, 'abc', True, 45.6, 300, 500]

# %%
#assignments
list1 = [12,23,45.6]
list1.sort(reverse=True)
list1
# Out:
# [45.6, 23, 12]

# %%
list1.sort()
list1
# Out:
# [12, 23, 45.6]

# %%
lis1 = [12,23,45.6,34,54]
lis1.index(12)
print(lis1)
# Out:
# [12, 23, 45.6, 34, 54]

# %%
list2 = list1.copy()
list2
# Out:
# [12, 23, 45.6, 34, 54]

# %%
list3 = list1.copy()
list3

# %%
list1.append(333)
list2.append(444)
list3.append(777)
print(list1,list2,list3)

# %%
list1.count(45.6)

# %%
##Accept 3 subjects marks of the students and store values in a list
##Return total maks of the student

list4 = []
for i in range(d)
  list4.append(int(input()))
print(list4)

# %%
n = int(input("enter num of sub"))
list4 = []
for i in range(n):
  list4.append(int(input()))
print("sum",sum(list4))

# %%
a = int(input("enter number of ele in list"))
li = []
for i in range(0,a):
  li.append(int(input()))
print("largest",max(li))

# %%
#Tuple -->indexed,ordered,allows duplicate values, immutable
#use()
t1 = (23,54,76,98)
lis2  = list(t1)
lis2[2] = 100
print(lis2)
print(lis2)
t1 = tuple(lis2)
print(lis2)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-59-1489502d41c5> in <module>()
#       1 t1 = (23,54,76,98)
# ----> 2 lis2  = list(t1)
#       3 lis2[2] = 100
#       4 print(lis2)
#       5 print(lis2)
#
# TypeError: 'list' object is not callable

# %%
# dict1 = {key1:value1,key2:value2,....}
# Rules for keys:
# 1.keys should be unique
# 2.keys should be immutable(numbers,strings,tuple)
s1 = {"name":"karthik","roll no":42,"course":"cse"}
#adding new entry
s1["addres"] = "hyd"
s1
# Out:
# {'addres': 'hyd', 'course': 'cse', 'name': 'karthik', 'roll no': 42}

# %%
del s1["course"]
s1
# Out:
# {'addres': 'hyd', 'name': 'karthik', 'roll no': 42}
